# %%
def track_changes(func):
    def wrapper(*args, **kwargs):
        # Save a copy of the original argument values
        arg_values = list(args)
        kwarg_values = dict(kwargs)
        
        # Save a copy of the original variable values
        initial_values = dict(func.__globals__)
        
        # Call the original function
        result = func(*args, **kwargs)
        
        # Check for changes to arguments
        for i, arg in enumerate(args):
            if arg != arg_values[i]:
                print(f'Argument {i+1} changed from {arg_values[i]} to {arg}')
        for kwarg, value in kwargs.items():
            if value != kwarg_values[kwarg]:
                print(f'Argument {kwarg} changed from {kwarg_values[kwarg]} to {value}')
        
        # Check for changes to variables
        for var_name, value in func.__globals__.items():
            if var_name.startswith('__') or value == initial_values[var_name]:
                continue
            print(f'{var_name} changed from {initial_values[var_name]} to {value}')
        
        return result
    
    return wrapper

# %%
@track_changes
def my_function(x, y, z=3):
    a = x + y
    b = z * 2
    x += 1
    y = 'hello'
    z += 3

# %%
my_function(1,2)

# %%
def track_changes(func):
    def wrapper(*args, **kwargs):
        initial_values = dict(func.__globals__)
        result = func(*args, **kwargs)
        for var_name, value in func.__globals__.items():
            if var_name.startswith('__') or value == initial_values[var_name]:
                continue
            print(f'{var_name} changed from {initial_values[var_name]} to {value}')
        return result
    return wrapper

# %%
@track_changes
def my_function():
    x = 1
    y = 'hello'
    x = 2
    y = 'world'

# %%
my_function()

# %%
def my_decorator(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called.")
    return wrapper

@my_decorator
def say_whee():
    print("Whee!")

# %%
say_whee()
# Out:
# Something is happening before the function is called.
# Whee!
# Something is happening after the function is called.

# %%
# program to display the functioning of
# settrace()
from sys import settrace


# local trace function which returns itself
def my_tracer(frame, event, arg = None):
	# extracts frame code
	code = frame.f_code

	# extracts calling function name
	func_name = code.co_name

	# extracts the line number
	line_no = frame.f_lineno

	print(f"A {event} encountered in \
	{func_name}() at line number {line_no} ")

	return my_tracer


# global trace function is invoked here and
# local trace function is set for fun()
def fun():
	return "GFG"


# global trace function is invoked here and
# local trace function is set for check()
def check():
	return fun()


# returns reference to local
# trace function (my_tracer)
settrace(my_tracer)

check()
# Out:
# A call encountered in 	__get__() at line number 566
# A line encountered in 	__get__() at line number 574
# A line encountered in 	__get__() at line number 577
# A call encountered in 	get() at line number 535
# A line encountered in 	get() at line number 536
# A line encountered in 	get() at line number 537
# A line encountered in 	get() at line number 564
# A return encountered in 	get() at line number 564
# A return encountered in 	__get__() at line number 577
# A call encountered in 	helper() at line number 261
# A line encountered in 	helper() at line number 263
# A call encountered in 	__init__() at line number 86
# A line encountered in 	__init__() at line number 87
# A line encountered in 	__init__() at line number 88
# A line encountered in 	__init__() at line number 90
# A line encountered in 	__init__() at line number 91
# A line encountered in 	__init__() at line number 92
# A line encountered in 	__init__() at line number 93
# A return encountered in 	__init__() at line number 93
# A return encountered in 	helper() at line number 263
# A call encountered in 	__enter__() at line number 114
# A line encountered in 	__enter__() at line number 117
# A line encountered in 	__enter__() at line number 118
# A line encountered in 	__enter__() at line number 119
# A call encountered in 	extra_flags() at line number 174
# A line encountered in 	extra_flags() at line number 177
# A line encountered in 	extra_flags() at line number 180
# A line encountered in 	extra_flags() at line number 181
# A line encountered in 	extra_flags() at line number 182
# A return encountered in 	extra_flags() at line number 182
# A return encountered in 	__enter__() at line number 119
# A call encountered in 	__call__() at line number 142
# A line encountered in 	__call__() at line number 143
# A line encountered in 	__call__() at line number 144
# A line encountered in 	__call__() at line number 145
# A line encountered in 	__call__() at line number 144
# A line encountered in 	__call__() at line number 145
# A line encountered in 	__call__() at line number 144
# A line encountered in 	__call__() at line number 145
# A line encountered in 	__call__() at line number 144
# A line encountered in 	__call__() at line number 145
# A line encountered in 	__call__() at line number 144
# A line encountered in 	__call__() at line number 145
# A line encountered in 	__call__() at line number 144
# A line encountered in 	__call__() at line number 145
# A line encountered in 	__call__() at line number 144
# A line encountered in 	__call__() at line number 145
# A line encountered in 	__call__() at line number 144
# A line encountered in 	__call__() at line number 145
# A line encountered in 	__call__() at line number 144
# A line encountered in 	__call__() at line number 145
# A line encountered in 	__call__() at line number 144
# A line encountered in 	__call__() at line number 145
# A line encountered in 	__call__() at line number 144
# A line encountered in 	__call__() at line number 147
# A return encountered in 	__call__() at line number 147
# A call encountered in 	_update_code_co_name() at line number 3186
# A line encountered in 	_update_code_co_name() at line number 3199
# A line encountered in 	_update_code_co_name() at line number 3203
# A line encountered in 	_update_code_co_name() at line number 3204
# A call encountered in 	findlinestarts() at line number 449
# A line encountered in 	findlinestarts() at line number 455
# A line encountered in 	findlinestarts() at line number 456
# A line encountered in 	findlinestarts() at line number 457
# A line encountered in 	findlinestarts() at line number 459
# A line encountered in 	findlinestarts() at line number 460
# A line encountered in 	findlinestarts() at line number 461
# A line encountered in 	findlinestarts() at line number 462
# A line encountered in 	findlinestarts() at line number 476
# A line encountered in 	findlinestarts() at line number 477
# A return encountered in 	findlinestarts() at line number 477
# A call encountered in 	findlinestarts() at line number 477
# A exception encountered in 	findlinestarts() at line number 477
# A return encountered in 	findlinestarts() at line number 477
# A line encountered in 	_update_code_co_name() at line number 3207
# A return encountered in 	_update_code_co_name() at line number 3207
# A call encountered in 	compare() at line number 3284
# A line encountered in 	compare() at line number 3285
# A line encountered in 	compare() at line number 3286
# A return encountered in 	compare() at line number 3286
# A call encountered in 	__exit__() at line number 123
# A line encountered in 	__exit__() at line number 124
# A line encountered in 	__exit__() at line number 125
# A line encountered in 	__exit__() at line number 126
# A call encountered in 	extra_flags() at line number 182
# A line encountered in 	extra_flags() at line number 186
# A return encountered in 	extra_flags() at line number 186
# A exception encountered in 	__exit__() at line number 126
# A line encountered in 	__exit__() at line number 127
# A line encountered in 	__exit__() at line number 128
# A return encountered in 	__exit__() at line number 128
# A call encountered in 	run_code() at line number 3333
# A line encountered in 	run_code() at line number 3355
# A line encountered in 	run_code() at line number 3358
# A line encountered in 	run_code() at line number 3362
# A line encountered in 	run_code() at line number 3363
# A line encountered in 	run_code() at line number 3364
# A line encountered in 	run_code() at line number 3365
# A line encountered in 	run_code() at line number 3366
# A line encountered in 	run_code() at line number 3369
# A call encountered in 	user_global_ns() at line number 1181
# A line encountered in 	user_global_ns() at line number 1183
# A return encountered in 	user_global_ns() at line number 1183
# A call encountered in 	<cell line: 39>() at line number 39
# A line encountered in 	<cell line: 39>() at line number 39
# A call encountered in 	check() at line number 31
# A line encountered in 	check() at line number 32
# A call encountered in 	fun() at line number 25
# A line encountered in 	fun() at line number 26
# A return encountered in 	fun() at line number 26
# A return encountered in 	check() at line number 32
# A call encountered in 	__call__() at line number 252
# A line encountered in 	__call__() at line number 258
# A call encountered in 	check_for_underscore() at line number 70
# A line encountered in 	check_for_underscore() at line number 75
# A return encountered in 	check_for_underscore() at line number 75
# A line encountered in 	__call__() at line number 259
# A call encountered in 	quiet() at line number 84
# A line encountered in 	quiet() at line number 88
# A line encountered in 	quiet() at line number 89
# A call encountered in 	__get__() at line number 566
# A line encountered in 	__get__() at line number 574
# A line encountered in 	__get__() at line number 577
# A call encountered in 	get() at line number 535
# A line encountered in 	get() at line number 536
# A line encountered in 	get() at line number 537
# A line encountered in 	get() at line number 564
# A return encountered in 	get() at line number 564
# A return encountered in 	__get__() at line number 577
# A call encountered in 	__get__() at line number 566
# A line encountered in 	__get__() at line number 574
# A line encountered in 	__get__() at line number 577
# A call encountered in 	get() at line number 535
# A line encountered in 	get() at line number 536
# A line encountered in 	get() at line number 537
# A line encountered in 	get() at line number 564
# A return encountered in 	get() at line number 564
# A return encountered in 	__get__() at line number 577
# A call encountered in 	__get__() at line number 566
# A line encountered in 	__get__() at line number 574
# A line encountered in 	__get__() at line number 577
# A call encountered in 	get() at line number 535
# A line encountered in 	get() at line number 536
# A line encountered in 	get() at line number 537
# A line encountered in 	get() at line number 564
# A return encountered in 	get() at line number 564
# A return encountered in 	__get__() at line number 577
# A line encountered in 	quiet() at line number 94
# A line encountered in 	quiet() at line number 95
# A call encountered in 	generate_tokens() at line number 612
# A line encountered in 	generate_tokens() at line number 618
# A return encountered in 	generate_tokens() at line number 618
# A call encountered in 	_tokenize() at line number 429
# A line encountered in 	_tokenize() at line number 430
# A line encountered in 	_tokenize() at line number 431
# A line encountered in 	_tokenize() at line number 432
# A line encountered in 	_tokenize() at line number 433
# A line encountered in 	_tokenize() at line number 434
# A line encountered in 	_tokenize() at line number 436
# A line encountered in 	_tokenize() at line number 441
# A line encountered in 	_tokenize() at line number 442
# A line encountered in 	_tokenize() at line number 444
# A line encountered in 	_tokenize() at line number 449
# A line encountered in 	_tokenize() at line number 450
# A line encountered in 	_tokenize() at line number 454
# A line encountered in 	_tokenize() at line number 456
# A line encountered in 	_tokenize() at line number 457
# A line encountered in 	_tokenize() at line number 459
# A line encountered in 	_tokenize() at line number 480
# A line encountered in 	_tokenize() at line number 481
# A line encountered in 	_tokenize() at line number 482
# A line encountered in 	_tokenize() at line number 483
# A line encountered in 	_tokenize() at line number 484
# A line encountered in 	_tokenize() at line number 486
# A line encountered in 	_tokenize() at line number 488
# A line encountered in 	_tokenize() at line number 493
# A line encountered in 	_tokenize() at line number 496
# A line encountered in 	_tokenize() at line number 497
# A line encountered in 	_tokenize() at line number 498
# A line encountered in 	_tokenize() at line number 499
# A line encountered in 	_tokenize() at line number 500
# A line encountered in 	_tokenize() at line number 499
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 499
# A call encountered in 	_tokenize() at line number 499
# A line encountered in 	_tokenize() at line number 501
# A line encountered in 	_tokenize() at line number 503
# A line encountered in 	_tokenize() at line number 504
# A line encountered in 	_tokenize() at line number 503
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 503
# A call encountered in 	_tokenize() at line number 503
# A line encountered in 	_tokenize() at line number 505
# A line encountered in 	_tokenize() at line number 444
# A line encountered in 	_tokenize() at line number 449
# A line encountered in 	_tokenize() at line number 450
# A line encountered in 	_tokenize() at line number 454
# A line encountered in 	_tokenize() at line number 456
# A line encountered in 	_tokenize() at line number 457
# A line encountered in 	_tokenize() at line number 459
# A line encountered in 	_tokenize() at line number 480
# A line encountered in 	_tokenize() at line number 481
# A line encountered in 	_tokenize() at line number 482
# A line encountered in 	_tokenize() at line number 483
# A line encountered in 	_tokenize() at line number 484
# A line encountered in 	_tokenize() at line number 486
# A line encountered in 	_tokenize() at line number 488
# A line encountered in 	_tokenize() at line number 493
# A line encountered in 	_tokenize() at line number 496
# A line encountered in 	_tokenize() at line number 497
# A line encountered in 	_tokenize() at line number 498
# A line encountered in 	_tokenize() at line number 499
# A line encountered in 	_tokenize() at line number 500
# A line encountered in 	_tokenize() at line number 499
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 499
# A call encountered in 	_tokenize() at line number 499
# A line encountered in 	_tokenize() at line number 501
# A line encountered in 	_tokenize() at line number 503
# A line encountered in 	_tokenize() at line number 504
# A line encountered in 	_tokenize() at line number 503
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 503
# A call encountered in 	_tokenize() at line number 503
# A line encountered in 	_tokenize() at line number 505
# A line encountered in 	_tokenize() at line number 444
# A line encountered in 	_tokenize() at line number 449
# A line encountered in 	_tokenize() at line number 450
# A line encountered in 	_tokenize() at line number 454
# A line encountered in 	_tokenize() at line number 456
# A line encountered in 	_tokenize() at line number 457
# A line encountered in 	_tokenize() at line number 459
# A line encountered in 	_tokenize() at line number 480
# A line encountered in 	_tokenize() at line number 481
# A line encountered in 	_tokenize() at line number 482
# A line encountered in 	_tokenize() at line number 483
# A line encountered in 	_tokenize() at line number 484
# A line encountered in 	_tokenize() at line number 486
# A line encountered in 	_tokenize() at line number 488
# A line encountered in 	_tokenize() at line number 493
# A line encountered in 	_tokenize() at line number 496
# A line encountered in 	_tokenize() at line number 507
# A line encountered in 	_tokenize() at line number 510
# A line encountered in 	_tokenize() at line number 524
# A line encountered in 	_tokenize() at line number 525
# A call encountered in 	_compile() at line number 98
# A line encountered in 	_compile() at line number 99
# A call encountered in 	compile() at line number 250
# A line encountered in 	compile() at line number 252
# A call encountered in 	_compile() at line number 289
# A line encountered in 	_compile() at line number 291
# A line encountered in 	_compile() at line number 292
# A call encountered in 	__get__() at line number 171
# A line encountered in 	__get__() at line number 172
# A line encountered in 	__get__() at line number 176
# A line encountered in 	__get__() at line number 178
# A call encountered in 	value() at line number 792
# A line encountered in 	value() at line number 795
# A return encountered in 	value() at line number 795
# A return encountered in 	__get__() at line number 178
# A line encountered in 	_compile() at line number 293
# A line encountered in 	_compile() at line number 294
# A return encountered in 	_compile() at line number 294
# A return encountered in 	compile() at line number 252
# A return encountered in 	_compile() at line number 99
# A line encountered in 	_tokenize() at line number 526
# A line encountered in 	_tokenize() at line number 527
# A line encountered in 	_tokenize() at line number 528
# A line encountered in 	_tokenize() at line number 529
# A line encountered in 	_tokenize() at line number 531
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 534
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 536
# A line encountered in 	_tokenize() at line number 542
# A line encountered in 	_tokenize() at line number 546
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 570
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 571
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 589
# A line encountered in 	_tokenize() at line number 590
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 590
# A call encountered in 	_tokenize() at line number 590
# A line encountered in 	_tokenize() at line number 524
# A line encountered in 	_tokenize() at line number 525
# A call encountered in 	_compile() at line number 98
# A line encountered in 	_compile() at line number 99
# A call encountered in 	compile() at line number 250
# A line encountered in 	compile() at line number 252
# A call encountered in 	_compile() at line number 289
# A line encountered in 	_compile() at line number 291
# A line encountered in 	_compile() at line number 292
# A call encountered in 	__get__() at line number 171
# A line encountered in 	__get__() at line number 172
# A line encountered in 	__get__() at line number 176
# A line encountered in 	__get__() at line number 178
# A call encountered in 	value() at line number 792
# A line encountered in 	value() at line number 795
# A return encountered in 	value() at line number 795
# A return encountered in 	__get__() at line number 178
# A line encountered in 	_compile() at line number 293
# A line encountered in 	_compile() at line number 294
# A return encountered in 	_compile() at line number 294
# A return encountered in 	compile() at line number 252
# A return encountered in 	_compile() at line number 99
# A line encountered in 	_tokenize() at line number 526
# A line encountered in 	_tokenize() at line number 527
# A line encountered in 	_tokenize() at line number 528
# A line encountered in 	_tokenize() at line number 529
# A line encountered in 	_tokenize() at line number 531
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 534
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 536
# A line encountered in 	_tokenize() at line number 542
# A line encountered in 	_tokenize() at line number 546
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 570
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 571
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 589
# A line encountered in 	_tokenize() at line number 590
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 590
# A call encountered in 	_tokenize() at line number 590
# A line encountered in 	_tokenize() at line number 524
# A line encountered in 	_tokenize() at line number 525
# A call encountered in 	_compile() at line number 98
# A line encountered in 	_compile() at line number 99
# A call encountered in 	compile() at line number 250
# A line encountered in 	compile() at line number 252
# A call encountered in 	_compile() at line number 289
# A line encountered in 	_compile() at line number 291
# A line encountered in 	_compile() at line number 292
# A call encountered in 	__get__() at line number 171
# A line encountered in 	__get__() at line number 172
# A line encountered in 	__get__() at line number 176
# A line encountered in 	__get__() at line number 178
# A call encountered in 	value() at line number 792
# A line encountered in 	value() at line number 795
# A return encountered in 	value() at line number 795
# A return encountered in 	__get__() at line number 178
# A line encountered in 	_compile() at line number 293
# A line encountered in 	_compile() at line number 294
# A return encountered in 	_compile() at line number 294
# A return encountered in 	compile() at line number 252
# A return encountered in 	_compile() at line number 99
# A line encountered in 	_tokenize() at line number 526
# A line encountered in 	_tokenize() at line number 527
# A line encountered in 	_tokenize() at line number 528
# A line encountered in 	_tokenize() at line number 529
# A line encountered in 	_tokenize() at line number 531
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 534
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 536
# A line encountered in 	_tokenize() at line number 542
# A line encountered in 	_tokenize() at line number 546
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 570
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 571
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 589
# A line encountered in 	_tokenize() at line number 590
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 590
# A call encountered in 	_tokenize() at line number 590
# A line encountered in 	_tokenize() at line number 524
# A line encountered in 	_tokenize() at line number 525
# A call encountered in 	_compile() at line number 98
# A line encountered in 	_compile() at line number 99
# A call encountered in 	compile() at line number 250
# A line encountered in 	compile() at line number 252
# A call encountered in 	_compile() at line number 289
# A line encountered in 	_compile() at line number 291
# A line encountered in 	_compile() at line number 292
# A call encountered in 	__get__() at line number 171
# A line encountered in 	__get__() at line number 172
# A line encountered in 	__get__() at line number 176
# A line encountered in 	__get__() at line number 178
# A call encountered in 	value() at line number 792
# A line encountered in 	value() at line number 795
# A return encountered in 	value() at line number 795
# A return encountered in 	__get__() at line number 178
# A line encountered in 	_compile() at line number 293
# A line encountered in 	_compile() at line number 294
# A return encountered in 	_compile() at line number 294
# A return encountered in 	compile() at line number 252
# A return encountered in 	_compile() at line number 99
# A line encountered in 	_tokenize() at line number 526
# A line encountered in 	_tokenize() at line number 527
# A line encountered in 	_tokenize() at line number 528
# A line encountered in 	_tokenize() at line number 529
# A line encountered in 	_tokenize() at line number 531
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 534
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 536
# A line encountered in 	_tokenize() at line number 542
# A line encountered in 	_tokenize() at line number 546
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 570
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 571
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 589
# A line encountered in 	_tokenize() at line number 590
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 590
# A call encountered in 	_tokenize() at line number 590
# A line encountered in 	_tokenize() at line number 524
# A line encountered in 	_tokenize() at line number 525
# A call encountered in 	_compile() at line number 98
# A line encountered in 	_compile() at line number 99
# A call encountered in 	compile() at line number 250
# A line encountered in 	compile() at line number 252
# A call encountered in 	_compile() at line number 289
# A line encountered in 	_compile() at line number 291
# A line encountered in 	_compile() at line number 292
# A call encountered in 	__get__() at line number 171
# A line encountered in 	__get__() at line number 172
# A line encountered in 	__get__() at line number 176
# A line encountered in 	__get__() at line number 178
# A call encountered in 	value() at line number 792
# A line encountered in 	value() at line number 795
# A return encountered in 	value() at line number 795
# A return encountered in 	__get__() at line number 178
# A line encountered in 	_compile() at line number 293
# A line encountered in 	_compile() at line number 294
# A return encountered in 	_compile() at line number 294
# A return encountered in 	compile() at line number 252
# A return encountered in 	_compile() at line number 99
# A line encountered in 	_tokenize() at line number 526
# A line encountered in 	_tokenize() at line number 527
# A line encountered in 	_tokenize() at line number 528
# A line encountered in 	_tokenize() at line number 529
# A line encountered in 	_tokenize() at line number 531
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 534
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 536
# A line encountered in 	_tokenize() at line number 537
# A line encountered in 	_tokenize() at line number 540
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 540
# A call encountered in 	_tokenize() at line number 540
# A line encountered in 	_tokenize() at line number 524
# A line encountered in 	_tokenize() at line number 444
# A line encountered in 	_tokenize() at line number 449
# A line encountered in 	_tokenize() at line number 450
# A line encountered in 	_tokenize() at line number 454
# A line encountered in 	_tokenize() at line number 456
# A line encountered in 	_tokenize() at line number 457
# A line encountered in 	_tokenize() at line number 459
# A line encountered in 	_tokenize() at line number 480
# A line encountered in 	_tokenize() at line number 481
# A line encountered in 	_tokenize() at line number 482
# A line encountered in 	_tokenize() at line number 483
# A line encountered in 	_tokenize() at line number 484
# A line encountered in 	_tokenize() at line number 486
# A line encountered in 	_tokenize() at line number 488
# A line encountered in 	_tokenize() at line number 493
# A line encountered in 	_tokenize() at line number 496
# A line encountered in 	_tokenize() at line number 497
# A line encountered in 	_tokenize() at line number 503
# A line encountered in 	_tokenize() at line number 504
# A line encountered in 	_tokenize() at line number 503
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 503
# A call encountered in 	_tokenize() at line number 503
# A line encountered in 	_tokenize() at line number 505
# A line encountered in 	_tokenize() at line number 444
# A line encountered in 	_tokenize() at line number 449
# A line encountered in 	_tokenize() at line number 450
# A line encountered in 	_tokenize() at line number 454
# A line encountered in 	_tokenize() at line number 456
# A line encountered in 	_tokenize() at line number 457
# A line encountered in 	_tokenize() at line number 459
# A line encountered in 	_tokenize() at line number 480
# A line encountered in 	_tokenize() at line number 481
# A line encountered in 	_tokenize() at line number 482
# A line encountered in 	_tokenize() at line number 483
# A line encountered in 	_tokenize() at line number 484
# A line encountered in 	_tokenize() at line number 486
# A line encountered in 	_tokenize() at line number 488
# A line encountered in 	_tokenize() at line number 493
# A line encountered in 	_tokenize() at line number 496
# A line encountered in 	_tokenize() at line number 497
# A line encountered in 	_tokenize() at line number 503
# A line encountered in 	_tokenize() at line number 504
# A line encountered in 	_tokenize() at line number 503
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 503
# A call encountered in 	_tokenize() at line number 503
# A line encountered in 	_tokenize() at line number 505
# A line encountered in 	_tokenize() at line number 444
# A line encountered in 	_tokenize() at line number 449
# A line encountered in 	_tokenize() at line number 450
# A line encountered in 	_tokenize() at line number 454
# A line encountered in 	_tokenize() at line number 456
# A line encountered in 	_tokenize() at line number 457
# A line encountered in 	_tokenize() at line number 459
# A line encountered in 	_tokenize() at line number 480
# A line encountered in 	_tokenize() at line number 481
# A line encountered in 	_tokenize() at line number 482
# A line encountered in 	_tokenize() at line number 483
# A line encountered in 	_tokenize() at line number 484
# A line encountered in 	_tokenize() at line number 486
# A line encountered in 	_tokenize() at line number 488
# A line encountered in 	_tokenize() at line number 493
# A line encountered in 	_tokenize() at line number 496
# A line encountered in 	_tokenize() at line number 497
# A line encountered in 	_tokenize() at line number 498
# A line encountered in 	_tokenize() at line number 499
# A line encountered in 	_tokenize() at line number 500
# A line encountered in 	_tokenize() at line number 499
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 499
# A call encountered in 	_tokenize() at line number 499
# A line encountered in 	_tokenize() at line number 501
# A line encountered in 	_tokenize() at line number 503
# A line encountered in 	_tokenize() at line number 504
# A line encountered in 	_tokenize() at line number 503
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 503
# A call encountered in 	_tokenize() at line number 503
# A line encountered in 	_tokenize() at line number 505
# A line encountered in 	_tokenize() at line number 444
# A line encountered in 	_tokenize() at line number 449
# A line encountered in 	_tokenize() at line number 450
# A line encountered in 	_tokenize() at line number 454
# A line encountered in 	_tokenize() at line number 456
# A line encountered in 	_tokenize() at line number 457
# A line encountered in 	_tokenize() at line number 459
# A line encountered in 	_tokenize() at line number 480
# A line encountered in 	_tokenize() at line number 481
# A line encountered in 	_tokenize() at line number 482
# A line encountered in 	_tokenize() at line number 483
# A line encountered in 	_tokenize() at line number 484
# A line encountered in 	_tokenize() at line number 486
# A line encountered in 	_tokenize() at line number 488
# A line encountered in 	_tokenize() at line number 493
# A line encountered in 	_tokenize() at line number 496
# A line encountered in 	_tokenize() at line number 507
# A line encountered in 	_tokenize() at line number 510
# A line encountered in 	_tokenize() at line number 524
# A line encountered in 	_tokenize() at line number 525
# A call encountered in 	_compile() at line number 98
# A line encountered in 	_compile() at line number 99
# A call encountered in 	compile() at line number 250
# A line encountered in 	compile() at line number 252
# A call encountered in 	_compile() at line number 289
# A line encountered in 	_compile() at line number 291
# A line encountered in 	_compile() at line number 292
# A call encountered in 	__get__() at line number 171
# A line encountered in 	__get__() at line number 172
# A line encountered in 	__get__() at line number 176
# A line encountered in 	__get__() at line number 178
# A call encountered in 	value() at line number 792
# A line encountered in 	value() at line number 795
# A return encountered in 	value() at line number 795
# A return encountered in 	__get__() at line number 178
# A line encountered in 	_compile() at line number 293
# A line encountered in 	_compile() at line number 294
# A return encountered in 	_compile() at line number 294
# A return encountered in 	compile() at line number 252
# A return encountered in 	_compile() at line number 99
# A line encountered in 	_tokenize() at line number 526
# A line encountered in 	_tokenize() at line number 527
# A line encountered in 	_tokenize() at line number 528
# A line encountered in 	_tokenize() at line number 529
# A line encountered in 	_tokenize() at line number 531
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 534
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 536
# A line encountered in 	_tokenize() at line number 542
# A line encountered in 	_tokenize() at line number 546
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 570
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 571
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 589
# A line encountered in 	_tokenize() at line number 590
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 590
# A call encountered in 	_tokenize() at line number 590
# A line encountered in 	_tokenize() at line number 524
# A line encountered in 	_tokenize() at line number 525
# A call encountered in 	_compile() at line number 98
# A line encountered in 	_compile() at line number 99
# A call encountered in 	compile() at line number 250
# A line encountered in 	compile() at line number 252
# A call encountered in 	_compile() at line number 289
# A line encountered in 	_compile() at line number 291
# A line encountered in 	_compile() at line number 292
# A call encountered in 	__get__() at line number 171
# A line encountered in 	__get__() at line number 172
# A line encountered in 	__get__() at line number 176
# A line encountered in 	__get__() at line number 178
# A call encountered in 	value() at line number 792
# A line encountered in 	value() at line number 795
# A return encountered in 	value() at line number 795
# A return encountered in 	__get__() at line number 178
# A line encountered in 	_compile() at line number 293
# A line encountered in 	_compile() at line number 294
# A return encountered in 	_compile() at line number 294
# A return encountered in 	compile() at line number 252
# A return encountered in 	_compile() at line number 99
# A line encountered in 	_tokenize() at line number 526
# A line encountered in 	_tokenize() at line number 527
# A line encountered in 	_tokenize() at line number 528
# A line encountered in 	_tokenize() at line number 529
# A line encountered in 	_tokenize() at line number 531
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 534
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 536
# A line encountered in 	_tokenize() at line number 542
# A line encountered in 	_tokenize() at line number 546
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 570
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 571
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 589
# A line encountered in 	_tokenize() at line number 590
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 590
# A call encountered in 	_tokenize() at line number 590
# A line encountered in 	_tokenize() at line number 524
# A line encountered in 	_tokenize() at line number 525
# A call encountered in 	_compile() at line number 98
# A line encountered in 	_compile() at line number 99
# A call encountered in 	compile() at line number 250
# A line encountered in 	compile() at line number 252
# A call encountered in 	_compile() at line number 289
# A line encountered in 	_compile() at line number 291
# A line encountered in 	_compile() at line number 292
# A call encountered in 	__get__() at line number 171
# A line encountered in 	__get__() at line number 172
# A line encountered in 	__get__() at line number 176
# A line encountered in 	__get__() at line number 178
# A call encountered in 	value() at line number 792
# A line encountered in 	value() at line number 795
# A return encountered in 	value() at line number 795
# A return encountered in 	__get__() at line number 178
# A line encountered in 	_compile() at line number 293
# A line encountered in 	_compile() at line number 294
# A return encountered in 	_compile() at line number 294
# A return encountered in 	compile() at line number 252
# A return encountered in 	_compile() at line number 99
# A line encountered in 	_tokenize() at line number 526
# A line encountered in 	_tokenize() at line number 527
# A line encountered in 	_tokenize() at line number 528
# A line encountered in 	_tokenize() at line number 529
# A line encountered in 	_tokenize() at line number 531
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 534
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 536
# A line encountered in 	_tokenize() at line number 542
# A line encountered in 	_tokenize() at line number 546
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 570
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 571
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 589
# A line encountered in 	_tokenize() at line number 591
# A line encountered in 	_tokenize() at line number 594
# A line encountered in 	_tokenize() at line number 595
# A line encountered in 	_tokenize() at line number 598
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 598
# A call encountered in 	_tokenize() at line number 598
# A line encountered in 	_tokenize() at line number 524
# A line encountered in 	_tokenize() at line number 525
# A call encountered in 	_compile() at line number 98
# A line encountered in 	_compile() at line number 99
# A call encountered in 	compile() at line number 250
# A line encountered in 	compile() at line number 252
# A call encountered in 	_compile() at line number 289
# A line encountered in 	_compile() at line number 291
# A line encountered in 	_compile() at line number 292
# A call encountered in 	__get__() at line number 171
# A line encountered in 	__get__() at line number 172
# A line encountered in 	__get__() at line number 176
# A line encountered in 	__get__() at line number 178
# A call encountered in 	value() at line number 792
# A line encountered in 	value() at line number 795
# A return encountered in 	value() at line number 795
# A return encountered in 	__get__() at line number 178
# A line encountered in 	_compile() at line number 293
# A line encountered in 	_compile() at line number 294
# A return encountered in 	_compile() at line number 294
# A return encountered in 	compile() at line number 252
# A return encountered in 	_compile() at line number 99
# A line encountered in 	_tokenize() at line number 526
# A line encountered in 	_tokenize() at line number 527
# A line encountered in 	_tokenize() at line number 528
# A line encountered in 	_tokenize() at line number 529
# A line encountered in 	_tokenize() at line number 531
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 534
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 536
# A line encountered in 	_tokenize() at line number 542
# A line encountered in 	_tokenize() at line number 546
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 570
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 571
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 589
# A line encountered in 	_tokenize() at line number 590
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 590
# A call encountered in 	_tokenize() at line number 590
# A line encountered in 	_tokenize() at line number 524
# A line encountered in 	_tokenize() at line number 525
# A call encountered in 	_compile() at line number 98
# A line encountered in 	_compile() at line number 99
# A call encountered in 	compile() at line number 250
# A line encountered in 	compile() at line number 252
# A call encountered in 	_compile() at line number 289
# A line encountered in 	_compile() at line number 291
# A line encountered in 	_compile() at line number 292
# A call encountered in 	__get__() at line number 171
# A line encountered in 	__get__() at line number 172
# A line encountered in 	__get__() at line number 176
# A line encountered in 	__get__() at line number 178
# A call encountered in 	value() at line number 792
# A line encountered in 	value() at line number 795
# A return encountered in 	value() at line number 795
# A return encountered in 	__get__() at line number 178
# A line encountered in 	_compile() at line number 293
# A line encountered in 	_compile() at line number 294
# A return encountered in 	_compile() at line number 294
# A return encountered in 	compile() at line number 252
# A return encountered in 	_compile() at line number 99
# A line encountered in 	_tokenize() at line number 526
# A line encountered in 	_tokenize() at line number 527
# A line encountered in 	_tokenize() at line number 528
# A line encountered in 	_tokenize() at line number 529
# A line encountered in 	_tokenize() at line number 531
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 534
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 536
# A line encountered in 	_tokenize() at line number 542
# A line encountered in 	_tokenize() at line number 546
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 570
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 571
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 589
# A line encountered in 	_tokenize() at line number 591
# A line encountered in 	_tokenize() at line number 594
# A line encountered in 	_tokenize() at line number 596
# A line encountered in 	_tokenize() at line number 598
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 598
# A call encountered in 	_tokenize() at line number 598
# A line encountered in 	_tokenize() at line number 524
# A line encountered in 	_tokenize() at line number 525
# A call encountered in 	_compile() at line number 98
# A line encountered in 	_compile() at line number 99
# A call encountered in 	compile() at line number 250
# A line encountered in 	compile() at line number 252
# A call encountered in 	_compile() at line number 289
# A line encountered in 	_compile() at line number 291
# A line encountered in 	_compile() at line number 292
# A call encountered in 	__get__() at line number 171
# A line encountered in 	__get__() at line number 172
# A line encountered in 	__get__() at line number 176
# A line encountered in 	__get__() at line number 178
# A call encountered in 	value() at line number 792
# A line encountered in 	value() at line number 795
# A return encountered in 	value() at line number 795
# A return encountered in 	__get__() at line number 178
# A line encountered in 	_compile() at line number 293
# A line encountered in 	_compile() at line number 294
# A return encountered in 	_compile() at line number 294
# A return encountered in 	compile() at line number 252
# A return encountered in 	_compile() at line number 99
# A line encountered in 	_tokenize() at line number 526
# A line encountered in 	_tokenize() at line number 527
# A line encountered in 	_tokenize() at line number 528
# A line encountered in 	_tokenize() at line number 529
# A line encountered in 	_tokenize() at line number 531
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 534
# A line encountered in 	_tokenize() at line number 533
# A line encountered in 	_tokenize() at line number 536
# A line encountered in 	_tokenize() at line number 542
# A line encountered in 	_tokenize() at line number 546
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 570
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 571
# A line encountered in 	_tokenize() at line number 569
# A line encountered in 	_tokenize() at line number 589
# A line encountered in 	_tokenize() at line number 590
# A call encountered in 	<lambda>() at line number 1
# A line encountered in 	<lambda>() at line number 1
# A return encountered in 	<lambda>() at line number 1
# A return encountered in 	_tokenize() at line number 590
# A call encountered in 	_tokenize() at line number 590
# A line encountered in 	_tokenize() at line number 524
# A line encountered in 	_tokenize() at line number 525
# A call encountered in 	_compile() at line number 98
# A line encountered in 	_compile() at line number 99
# A call encountered in 	compile() at line number 250
# A line encountered in 	compile() at line number 252
# A call encountered in 	_compile() at line number 289
# A line encountered in 	_compile() at line number 291
# A line encountered in 	_compile() at line number 292
# A call encountered in 	__get__() at line number 171
# A line encountered in 	__get__() at line number 172
# A line encountered in 	__get__() at line number 176
# A line encountered in 	__get__() at line number 178
# A call encountered in 	value() at line number 792
# A line encountered in 	value() at line number 795
# A return encountered in 	value() at line number 795
# A return encountered in 	__get__() at line number 178
# A line encountered in 	_compile() at line number 293
# A line encountered in 	_compile() at line number 294
# A return encountered in 	_compile() at line number 294
# A return encountered in 	compile() at line number 252
# A return encountered in 	_compile() at line number 99
# A line encountered in 	_tokenize() at line number 526
# A line encountered in 	_tokenize() at line number 527
# A line encountered in 	_tokenize() at line number 528
# A line encountered in 	_tokenize() at line number 529
# A line encountered in 	_tokenize() at line number 531
# A line encountered in 	_tokenize() at line number 533
# ...
# A line encountered in 	__enter__() at line number 257
# A return encountered in 	__enter__() at line number 257
# A line encountered in 	cancelled() at line number 376
# A call encountered in 	__exit__() at line number 259
# A line encountered in 	__exit__() at line number 260
# A return encountered in 	__exit__() at line number 260
# A return encountered in 	cancelled() at line number 376
# A line encountered in 	_copy_future_state() at line number 354
# A call encountered in 	exception() at line number 453
# A line encountered in 	exception() at line number 471
# A call encountered in 	__enter__() at line number 256
# A line encountered in 	__enter__() at line number 257
# A return encountered in 	__enter__() at line number 257
# A line encountered in 	exception() at line number 472
# A line encountered in 	exception() at line number 474
# A line encountered in 	exception() at line number 475
# A call encountered in 	__exit__() at line number 259
# A line encountered in 	__exit__() at line number 260
# A return encountered in 	__exit__() at line number 260
# A return encountered in 	exception() at line number 475
# A line encountered in 	_copy_future_state() at line number 355
# A line encountered in 	_copy_future_state() at line number 358
# A call encountered in 	result() at line number 418
# A line encountered in 	result() at line number 434
# A line encountered in 	result() at line number 435
# A call encountered in 	__enter__() at line number 256
# A line encountered in 	__enter__() at line number 257
# A return encountered in 	__enter__() at line number 257
# A line encountered in 	result() at line number 436
# A line encountered in 	result() at line number 438
# A line encountered in 	result() at line number 439
# A call encountered in 	__get_result() at line number 388
# A line encountered in 	__get_result() at line number 389
# A line encountered in 	__get_result() at line number 396
# A return encountered in 	__get_result() at line number 396
# A call encountered in 	__exit__() at line number 259
# A line encountered in 	__exit__() at line number 260
# A return encountered in 	__exit__() at line number 260
# A line encountered in 	result() at line number 451
# A line encountered in 	result() at line number 439
# A return encountered in 	result() at line number 439
# A line encountered in 	_copy_future_state() at line number 359
# A call encountered in 	call_soon() at line number 741
# A line encountered in 	call_soon() at line number 751
# A call encountered in 	_check_closed() at line number 513
# A line encountered in 	_check_closed() at line number 514
# A return encountered in 	_check_closed() at line number 514
# A line encountered in 	call_soon() at line number 752
# A line encountered in 	call_soon() at line number 755
# A call encountered in 	_call_soon() at line number 770
# A line encountered in 	_call_soon() at line number 771
# A call encountered in 	__init__() at line number 31
# A line encountered in 	__init__() at line number 32
# A line encountered in 	__init__() at line number 34
# A line encountered in 	__init__() at line number 35
# A line encountered in 	__init__() at line number 36
# A line encountered in 	__init__() at line number 37
# A line encountered in 	__init__() at line number 38
# A line encountered in 	__init__() at line number 39
# A line encountered in 	__init__() at line number 40
# A call encountered in 	get_debug() at line number 1923
# A line encountered in 	get_debug() at line number 1924
# A return encountered in 	get_debug() at line number 1924
# A line encountered in 	__init__() at line number 44
# A return encountered in 	__init__() at line number 44
# A line encountered in 	_call_soon() at line number 772
# A line encountered in 	_call_soon() at line number 774
# A line encountered in 	_call_soon() at line number 775
# A return encountered in 	_call_soon() at line number 775
# A line encountered in 	call_soon() at line number 756
# A line encountered in 	call_soon() at line number 758
# A return encountered in 	call_soon() at line number 758
# A return encountered in 	_copy_future_state() at line number 359
# A return encountered in 	_set_state() at line number 380
# A line encountered in 	_run() at line number 95
# A return encountered in 	_run() at line number 95
# A line encountered in 	_run_once() at line number 1889
# A line encountered in 	_run_once() at line number 1890
# A line encountered in 	_run_once() at line number 1891
# A line encountered in 	_run_once() at line number 1893
# A line encountered in 	_run_once() at line number 1905
# A call encountered in 	_run() at line number 78
# A line encountered in 	_run() at line number 79
# A line encountered in 	_run() at line number 80
# A call encountered in 	_run_callback() at line number 733
# A line encountered in 	_run_callback() at line number 740
# A line encountered in 	_run_callback() at line number 741
# A call encountered in 	<lambda>() at line number 536
# A line encountered in 	<lambda>() at line number 536
# A call encountered in 	_handle_events() at line number 438
# A line encountered in 	_handle_events() at line number 441
# A line encountered in 	_handle_events() at line number 444
# A line encountered in 	_handle_events() at line number 445
# A call encountered in 	__getattr__() at line number 38
# A line encountered in 	__getattr__() at line number 40
# A line encountered in 	__getattr__() at line number 41
# A line encountered in 	__getattr__() at line number 42
# A line encountered in 	__getattr__() at line number 48
# A call encountered in 	_handle_fromlist() at line number 1033
# A line encountered in 	_handle_fromlist() at line number 1043
# A line encountered in 	_handle_fromlist() at line number 1044
# A line encountered in 	_handle_fromlist() at line number 1051
# A line encountered in 	_handle_fromlist() at line number 1055
# A line encountered in 	_handle_fromlist() at line number 1043
# A line encountered in 	_handle_fromlist() at line number 1067
# A return encountered in 	_handle_fromlist() at line number 1067
# A line encountered in 	__getattr__() at line number 50
# A line encountered in 	__getattr__() at line number 51
# A call encountered in 	_get_attr_opt() at line number 61
# A line encountered in 	_get_attr_opt() at line number 63
# A return encountered in 	_get_attr_opt() at line number 63
# A return encountered in 	__getattr__() at line number 51
# A line encountered in 	_handle_events() at line number 449
# A line encountered in 	_handle_events() at line number 451
# A line encountered in 	_handle_events() at line number 455
# A call encountered in 	sending() at line number 412
# A line encountered in 	sending() at line number 414
# A call encountered in 	empty() at line number 97
# A line encountered in 	empty() at line number 108
# A line encountered in 	empty() at line number 109
# A call encountered in 	_qsize() at line number 209
# A line encountered in 	_qsize() at line number 210
# A return encountered in 	_qsize() at line number 210
# A return encountered in 	empty() at line number 109
# A return encountered in 	sending() at line number 414
# A line encountered in 	_handle_events() at line number 461
# A call encountered in 	_rebuild_io_state() at line number 505
# A line encountered in 	_rebuild_io_state() at line number 507
# A line encountered in 	_rebuild_io_state() at line number 509
# A line encountered in 	_rebuild_io_state() at line number 510
# A call encountered in 	receiving() at line number 408
# A line encountered in 	receiving() at line number 410
# A return encountered in 	receiving() at line number 410
# A line encountered in 	_rebuild_io_state() at line number 511
# A line encountered in 	_rebuild_io_state() at line number 512
# A call encountered in 	sending() at line number 412
# A line encountered in 	sending() at line number 414
# A call encountered in 	empty() at line number 97
# A line encountered in 	empty() at line number 108
# A line encountered in 	empty() at line number 109
# A call encountered in 	_qsize() at line number 209
# A line encountered in 	_qsize() at line number 210
# A return encountered in 	_qsize() at line number 210
# A return encountered in 	empty() at line number 109
# A return encountered in 	sending() at line number 414
# A line encountered in 	_rebuild_io_state() at line number 515
# A line encountered in 	_rebuild_io_state() at line number 516
# A call encountered in 	_update_handler() at line number 528
# A line encountered in 	_update_handler() at line number 530
# A line encountered in 	_update_handler() at line number 533
# A call encountered in 	__getattr__() at line number 38
# A line encountered in 	__getattr__() at line number 40
# A line encountered in 	__getattr__() at line number 41
# A line encountered in 	__getattr__() at line number 42
# A line encountered in 	__getattr__() at line number 48
# A call encountered in 	_handle_fromlist() at line number 1033
# A line encountered in 	_handle_fromlist() at line number 1043
# A line encountered in 	_handle_fromlist() at line number 1044
# A line encountered in 	_handle_fromlist() at line number 1051
# A line encountered in 	_handle_fromlist() at line number 1055
# A line encountered in 	_handle_fromlist() at line number 1043
# A line encountered in 	_handle_fromlist() at line number 1067
# A return encountered in 	_handle_fromlist() at line number 1067
# A line encountered in 	__getattr__() at line number 50
# A line encountered in 	__getattr__() at line number 51
# A call encountered in 	_get_attr_opt() at line number 61
# A line encountered in 	_get_attr_opt() at line number 63
# A return encountered in 	_get_attr_opt() at line number 63
# A return encountered in 	__getattr__() at line number 51
# A return encountered in 	_update_handler() at line number 533
# A return encountered in 	_rebuild_io_state() at line number 516
# A return encountered in 	_handle_events() at line number 461
# A return encountered in 	<lambda>() at line number 536
# A line encountered in 	_run_callback() at line number 742
# A return encountered in 	_run_callback() at line number 742
# A line encountered in 	_run() at line number 95
# A return encountered in 	_run() at line number 95
# A line encountered in 	_run_once() at line number 1889
# A line encountered in 	_run_once() at line number 1890
# A line encountered in 	_run_once() at line number 1891
# A line encountered in 	_run_once() at line number 1893
# A line encountered in 	_run_once() at line number 1905
# A call encountered in 	_run() at line number 78
# A line encountered in 	_run() at line number 79
# A line encountered in 	_run() at line number 80
# A call encountered in 	_run_callback() at line number 733
# A line encountered in 	_run_callback() at line number 740
# A line encountered in 	_run_callback() at line number 741
# A call encountered in 	_finish_flush() at line number 294
# A line encountered in 	_finish_flush() at line number 296
# A return encountered in 	_finish_flush() at line number 296
# A line encountered in 	_run_callback() at line number 742
# A return encountered in 	_run_callback() at line number 742
# A line encountered in 	_run() at line number 95
# A return encountered in 	_run() at line number 95
# A line encountered in 	_run_once() at line number 1889
# A line encountered in 	_run_once() at line number 1890
# A line encountered in 	_run_once() at line number 1891
# A line encountered in 	_run_once() at line number 1893
# A line encountered in 	_run_once() at line number 1905
# A call encountered in 	_run() at line number 78
# A line encountered in 	_run() at line number 79
# A line encountered in 	_run() at line number 80
# A call encountered in 	_read_from_self() at line number 112
# A line encountered in 	_read_from_self() at line number 114
# A line encountered in 	_read_from_self() at line number 115
# A line encountered in 	_read_from_self() at line number 116
# A line encountered in 	_read_from_self() at line number 118
# A call encountered in 	_process_self_data() at line number 71
# A line encountered in 	_process_self_data() at line number 72
# A line encountered in 	_process_self_data() at line number 73
# A line encountered in 	_process_self_data() at line number 75
# A line encountered in 	_process_self_data() at line number 72
# A return encountered in 	_process_self_data() at line number 72
# A line encountered in 	_read_from_self() at line number 114
# A line encountered in 	_read_from_self() at line number 115
# A exception encountered in 	_read_from_self() at line number 115
# A line encountered in 	_read_from_self() at line number 119
# A line encountered in 	_read_from_self() at line number 121
# A line encountered in 	_read_from_self() at line number 122
# A return encountered in 	_read_from_self() at line number 122
# A line encountered in 	_run() at line number 95
# A return encountered in 	_run() at line number 95
# A line encountered in 	_run_once() at line number 1889
# A line encountered in 	_run_once() at line number 1906
# A return encountered in 	_run_once() at line number 1906
# A call encountered in 	_run_once() at line number 1830
# A line encountered in 	_run_once() at line number 1838
# A line encountered in 	_run_once() at line number 1839
# A line encountered in 	_run_once() at line number 1856
# A line encountered in 	_run_once() at line number 1861
# A line encountered in 	_run_once() at line number 1862
# A line encountered in 	_run_once() at line number 1863
# A line encountered in 	_run_once() at line number 1869
# A call encountered in 	select() at line number 554
# A line encountered in 	select() at line number 555
# A line encountered in 	select() at line number 559
# A line encountered in 	select() at line number 560
# A line encountered in 	select() at line number 561
# A line encountered in 	select() at line number 562
# A line encountered in 	select() at line number 565
# A line encountered in 	select() at line number 577
# A return encountered in 	select() at line number 577
# A line encountered in 	_run_once() at line number 1870
# A call encountered in 	_process_events() at line number 591
# A line encountered in 	_process_events() at line number 592
# A return encountered in 	_process_events() at line number 592
# A line encountered in 	_run_once() at line number 1873
# A call encountered in 	time() at line number 694
# A line encountered in 	time() at line number 701
# A return encountered in 	time() at line number 701
# A line encountered in 	_run_once() at line number 1874
# A line encountered in 	_run_once() at line number 1888
# A line encountered in 	_run_once() at line number 1889
# A line encountered in 	_run_once() at line number 1890
# A line encountered in 	_run_once() at line number 1891
# A line encountered in 	_run_once() at line number 1893
# A line encountered in 	_run_once() at line number 1905
# A call encountered in 	_run() at line number 78
# A line encountered in 	_run() at line number 79
# A line encountered in 	_run() at line number 80
# A call encountered in 	_call_check_cancel() at line number 384
# A line encountered in 	_call_check_cancel() at line number 385
# A return encountered in 	_call_check_cancel() at line number 385
# A line encountered in 	_run() at line number 95
# A return encountered in 	_run() at line number 95
# A line encountered in 	_run_once() at line number 1889
# A line encountered in 	_run_once() at line number 1906
# A return encountered in 	_run_once() at line number 1906
# A call encountered in 	_run_once() at line number 1830
# A line encountered in 	_run_once() at line number 1838
# A line encountered in 	_run_once() at line number 1839
# A line encountered in 	_run_once() at line number 1856
# A line encountered in 	_run_once() at line number 1861
# A line encountered in 	_run_once() at line number 1862
# A line encountered in 	_run_once() at line number 1864
# A line encountered in 	_run_once() at line number 1869
# A call encountered in 	select() at line number 554
# A line encountered in 	select() at line number 555
# A line encountered in 	select() at line number 559
# A line encountered in 	select() at line number 560
# A line encountered in 	select() at line number 561
# A line encountered in 	select() at line number 562
